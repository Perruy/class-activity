# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# the next step I load the image in grayscale

# %%
image_path = "/content/einstein.tif"
original_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# %%
#here I display it using matplot library
plt.figure(figsize=(6,5))
plt.imshow(original_image, cmap="gray")
plt.title("Original Grayscale Image")
plt.axis("off")
plt.show()

# %% [markdown]
# thirdly I display the negative image.

# %%
negative_image = 255 - original_image #this is the most simpliest means of doing and then I plot it using matplot
plt.figure(figsize=(6,6))
plt.imshow(negative_image, cmap="gray")
plt.title("Negative Image")
plt.axis("off")
plt.show()

# %% [markdown]
# the last step I  get the intensity value of 5 random pixels, and from the negative image
# get the intensity value of same pixels. Print pixel values to show pixel values before and after

# %%
print("values after negation:")
for x, y in random_pixels:
    original_intensity = original_image[y, x]
    negative_intensity = negative_image[y, x]
    print(f"Pixel at ({x}, {y}): Original = {original_intensity}, Negative = {negative_intensity}")
# Out:
# values after negation:
# Pixel at (758, 558): Original = 98, Negative = 157
# Pixel at (89, 604): Original = 99, Negative = 156
# Pixel at (432, 32): Original = 112, Negative = 143
# Pixel at (30, 95): Original = 100, Negative = 155
# Pixel at (223, 238): Original = 108, Negative = 147
